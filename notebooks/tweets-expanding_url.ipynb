# %% [markdown]
# # load data

# %%
import json
import sqlite3
import pandas as pd
import re
from urllib.parse import urlparse
from requests_html import HTMLSession

# %%
from datetime import date
from datetime import timedelta

# %% [markdown]
# ## load tweets older then two weeks

# %%
# this part is needed to import local modules to jupyter notebook
import os
import sys

module_path = os.path.abspath(os.path.join(".."))
if module_path not in sys.path:
    sys.path.append(module_path + "/tweetfeed")

from data import load_tweets

# %%
# data keep on coming - to work on a static dataset I saved it once to pickle

# %%
# df_tweets = load_tweets("../home.db", days=0)
# df_tweets = df_tweets[df_tweets.retweeted_status == "N/A"] # remove RT
# df_tweets.to_pickle("shorturl.pkl")

# %%
df_tweets = pd.read_pickle("shorturl.pkl")
df_tweets.shape
# Out:
# (74869, 9)

# %% [markdown]
# # utils

# %%
df_tweets.tail()
# Out:
#                         id        user  \
# 95305  1359964994532614144  2178012643
# 95306  1359965511396675585    15626406
# 95307  1359965679110287360   259034658
# 95308  1359965833502494722      817386
# 95309  1359965919028547587  1416500532
#
#                                                full_text  \
# 95305  It’s one thing to ban violent crimes, universa...
# 95306  (It would plausibly reduce corn subsidies - le...
# 95307                            Winter dopamine famine.
# 95308  Google adds some of its Pixel-exclusive photo ...
# 95309          And just like that, a migraine emerges,,,
#
#                       created_at lang retweeted_status quoted_status  \
# 95305  2021-02-11T20:38:16+00:00   en              N/A           N/A
# 95306  2021-02-11T20:40:19+00:00   en              N/A           N/A
# 95307  2021-02-11T20:40:59+00:00   de              N/A           N/A
# 95308  2021-02-11T20:41:36+00:00   en              N/A           N/A
# 95309  2021-02-11T20:41:56+00:00   en              N/A           N/A
#
#        is_quote_status in_reply_to_status_id
# 95305                0   1359963436117938178
# 95306                0   1359964356541181952
# 95307                0                   N/A
# 95308                0                   N/A
# 95309                0                   N/A

# %%
# way of extracting titles from urls
url = "https://lukecarneal.substack.com/p/why-are-some-organic-farmers-turning"
print(HTMLSession().get(url).html.find("title", first=True).text)
# Out:
# Why Are Some Organic Farmers Turning to Reactionary Politics? - The Farm Worker Bulletin

# %%
def grab_title(url):
    try:
        title = HTMLSession().get(url).html.find("title", first=True).text
        return title
    except Exception as ex:
        return 0

# %%
# %%time
url = "https://buff.ly/2T4jips"
grab_title(url)
# Out:
# CPU times: user 69.9 ms, sys: 0 ns, total: 69.9 ms
# Wall time: 2.31 s
# '3 Tiny Mental Habits I Practice Every Morning – In Less Than 5 Minutes'

# %% [markdown]
# ## Utils

# %%
def rem_short_links(tweet: str) -> str:
    """removes some of short links (bit.ly, buff.ly, t.co) from tweets"""
    tweet = re.sub(r"https://bit.ly/\S+", "", tweet)
    tweet = re.sub(r"http://bit.ly/\S+", "", tweet)
    tweet = re.sub(r"https://buff.ly/\S+", "", tweet)
    tweet = re.sub(r"http://buff.ly/\S+", "", tweet)
    tweet = re.sub(r"https://t.co/\S+", "", tweet)
    tweet = re.sub(r"http://t.co/\S+", "", tweet)
    return tweet

# %%
# my find_news function drops unnecessery columns, but for this task they are needed, so I modify it a little

from data import remove_tw_urls, find_url, get_domain, remove_empty_str

def find_news(df, news_domains_list):
    df = df.copy()
    df["clean_text"] = df["full_text"].apply(remove_tw_urls).apply(rem_short_links)
    df["clean_text"] = df["clean_text"].apply(rem_short_links)
    df["urls"] = df["clean_text"].apply(find_url)
    df.drop(["clean_text"], axis=1, inplace=True)
    df["domains"] = df.urls.apply(lambda x: [get_domain(d) for d in x])
    df["domains"] = df.domains.apply(remove_empty_str)
    # df.drop(["urls"], axis=1, inplace=True)

    new_columns_list = []
    max_nr_dom = df.domains.str.len().max()
    for i in range(max_nr_dom):
        new_columns_list.append(f"domain{i+1}")
    df.reset_index(drop=True, inplace=True)
    df[new_columns_list] = pd.DataFrame(df.domains.tolist())

    for col in new_columns_list:
        df[col] = df[col].isin(news_domains_list)

    #     df.drop(["domains"], axis=1, inplace=True)

    df["contains_news"] = df[new_columns_list].sum(axis=1)
    df["contains_news"] = df.contains_news.apply(lambda x: x if x == 0 else 1)
    df.drop(new_columns_list, axis=1, inplace=True)

    return df

# %%
def drop_contains(df, column_name, word_list):
    for string in word_list:
        df["lower"] = df["full_text"].str.lower()
        df = df[df["lower"].str.contains(string)]
        df.drop(["lower"], axis=1, inplace=True)
    return df

# %% [markdown]
# # searching for not-expanded news urls

# %%
dfz = df_tweets.copy()

# %%
with open("20200223_news_domains.txt", "r") as f:
    news_domains = json.loads(f.read())

# %%
dfz = find_news(dfz, news_domains)

# %%
dfz["has_domain"] = dfz.domains.apply(lambda x: len(x))

# %%
dfz.head()
# Out:
#                     id        user  \
# 7    35466982635601920    15012642
# 25  451159870306549761   159169312
# 34  563101166771650561  1460035021
# 35  574518676575162369    68132773
# 39  627427921624481792   794010396
#
#                                             full_text  \
# 7   #Bitcoin reaches parity with the US Dollar!  h...
# 25  Course slides from @Stanford and @stanfordsyms...
# 34  Watched Vincent Price in "Confessions of an Op...
# 35  Robert Capa's Omaha Beach by Dominique Bertail...
# 39  600cals per day for 7 days reverses T2 diabete...
#
#                    created_at lang retweeted_status quoted_status  \
# 7   2011-02-09T22:36:02+00:00   en              N/A           N/A
# 25  2014-04-02T00:51:09+00:00   en              N/A           N/A
# 34  2015-02-04T22:25:54+00:00   en              N/A           N/A
# 35  2015-03-08T10:35:01+00:00   en              N/A           N/A
# 39  2015-08-01T10:37:28+00:00   en              N/A           N/A
#
#     is_quote_status in_reply_to_status_id  \
# 7                 0                   N/A
# 25                0                   N/A
# 34                0                   N/A
# 35                0                   N/A
# 39                0                   N/A
#
#                                                  urls  \
# 7                 [http://bitcoincharts.com/markets/]
# 25              [http://stanford.edu/~zdar/week1.pdf]
# 34  [http://imdb.com/rg/an_share/title/title/tt005...
# 35  [http://bandedessinee.blog.lemonde.fr/2014/06/...
# 39  [http://link.springer.com/article/10.1007/s001...
#
#                             domains  contains_news  has_domain
# 7               [bitcoincharts.com]              0           1
# 25                   [stanford.edu]              0           1
# 34                       [imdb.com]              0           1
# 35  [bandedessinee.blog.lemonde.fr]              0           1
# 39                   [springer.com]              0           1

# %%
# take tweets that have domains
dfz = dfz[dfz.has_domain > 0]
dfz.shape
# Out:
# (15120, 13)

# %%
# let's grab only those WITHOUT news
dfz = dfz[dfz.contains_news == 0]
dfz.shape
# Out:
# (15120, 13)

# %%
import warnings; warnings.simplefilter('ignore')
# response = HTMLSession().get(link, verify=False) will generate warnings

# %%
# import json

# # short_url =[]
# with open("short_url.json") as json_file:
#     short_url = json.load(json_file)
# urls_list = pd.DataFrame(short_url).url.tolist()

# x = 0
# for c, i in enumerate(dfz.urls[x:]):
#     print(c + x, i)
#     if (c + x + 1) % 100 == 0:
#         print(f"{(c+1)} / {len(dfz.urls)}")
#     for link in i:
#         print(c+x)
#         if link in urls_list:
#             pass

#         else:
#             try:
#                 char_to_rem = "',)\"!"
#                 for char in char_to_rem:
#                     link = link.replace(char, "")
#                 if link.split(".")[-1] == "pdf":
#                     short_url.append(
#                         {
#                             "url": link,
#                             "links": i,
#                             "idx": c+x,
#                             "error": "pdf",
#                         }
#                     )
#                 else:
#                     domain = get_domain(link)
#                     response = HTMLSession().get(link, verify=False)
#                     e_link = response.url
#                     response.html.find('title', first=True).text
#                     dom_expanded = get_domain(e_link)
#                     short_url.append(
#                         {
#                             "url": link,
#                             "title": response.html.find('title', first=True).text,
#                             "short_url": domain,
#                             "long_url": dom_expanded,
#                             "is_news": (dom_expanded in news_domains),
#                             "diff_url": (dom_expanded != domain),
#                         }
#                     )
#             except Exception as ex:
#                 short_url.append(
#                     {
#                         "url": link,
#                         "links": i,
#                         "idx": c+x,
#                         "error": str(ex),
#                     }
#                 )
#     with open("short_url.json", "w") as file:
#         file.write(json.dumps(short_url, indent=4))

# %% [markdown]
# ## Analyse short links

# %%
# use short url list
with open("short_url.json") as json_file:
    short_url = json.load(json_file)

# %%
short_url = pd.DataFrame.from_dict(short_url)
# select only short urls, if their long url is in news
short_url_news = short_url[short_url.is_news == True].short_url.unique().tolist()

# %%
short_url_news
# Out:
# ['bloom.bg',
#  'nyti.ms',
#  'cnb.cx',
#  'rdcu.be',
#  'trib.al',
#  'ti.me',
#  'on.theatln.tc',
#  'reut.rs',
#  'zd.net',
#  'afp.com',
#  'ow.ly',
#  'google.com',
#  'tcrn.ch',
#  'st.news',
#  'wp.me',
#  'thr.cm',
#  'apne.ws',
#  'bbc.in',
#  'petitions.whitehouse.gov',
#  'dlvr.it',
#  'action.consumerreports.org',
#  'politi.co',
#  'econ.st',
#  'washex.am',
#  'str.sg',
#  'jtim.es',
#  'google.it',
#  'cnn.it',
#  'abc7ne.ws',
#  'wapo.st',
#  'go.usa.gov',
#  'vntyfr.com',
#  'b-gat.es',
#  'nie.mn',
#  'mtr.cool',
#  'propub.li',
#  'to.pbs.org',
#  'ellemag.co',
#  'mitsln.co',
#  'hill.cm',
#  'cos.lv',
#  'ift.tt',
#  '1843m.ag',
#  'bos.gl',
#  'nzzl.us',
#  'tdrt.io',
#  'wdrb.news',
#  'nytimes.com',
#  '53eig.ht',
#  'tmz.me',
#  'ja.ma',
#  'dailym.ai',
#  'mol.im',
#  'yhoo.it',
#  'nationalenquirer.com',
#  'nvda.ws',
#  'wired.trib.al',
#  'sabahdai.ly',
#  'lnkd.in',
#  'nym.ag',
#  'cnet.co',
#  'buildbackbetter.gov',
#  'WhiteHouse.gov',
#  'pewrsr.ch',
#  '808ne.ws',
#  'sc.mp',
#  'cntrvlr.co',
#  'on.mktw.net',
#  'zcu.io',
#  'ibm.co',
#  'Whitehouse.gov',
#  'whitehouse.gov.',
#  'cbsn.ws',
#  'p4k.in',
#  'engt.co',
#  'cutt.ly',
#  'dpmd.ai',
#  'abc30.tv',
#  'flip.it',
#  'slate.trib.al',
#  'abc7.la',
#  'rol.st',
#  'cityjourn.al',
#  'go.shr.lc',
#  'wrctr.co',
#  'natgeo.com',
#  'bddy.me',
#  'vult.re',
#  '4NN.cx']

# %%
# filter dataframe to just short url that expand into news urls
df = short_url[short_url.short_url.isin(short_url_news)]
df["is_news"] = df.is_news.astype(int)

# %%
df.head()
# Out:
#                           url  \
# 11    http://bloom.bg/2iqJnMo
# 12    https://nyti.ms/2nMAShX
# 17   http://ow.ly/QHDf30fzBjh
# 66    https://nyti.ms/2ZsakYf
# 124    https://cnb.cx/2Wya3zC
#
#                                                  title short_url  \
# 11   This Mile High Club Will Come With Drinks and ...  bloom.bg
# 12   How Uber Uses Psychological Tricks to Push Its...   nyti.ms
# 17                                  Carme Torras Genís     ow.ly
# 66   Humans Are Impetuous and Shortsighted. Can We ...   nyti.ms
# 124  NY Gov. Cuomo says he won't sacrifice human li...    cnb.cx
#
#           long_url  is_news diff_url  idx error links
# 11   bloomberg.com        1     True  NaN   NaN   NaN
# 12     nytimes.com        1     True  NaN   NaN   NaN
# 17     iri.upc.edu        0     True  NaN   NaN   NaN
# 66     nytimes.com        1     True  NaN   NaN   NaN
# 124       cnbc.com        1     True  NaN   NaN   NaN

# %%
# calculate procentage of times short url domain leads to news site
dfgb = df.groupby(by=["short_url"]).sum()
s = df.short_url.value_counts()
df = dfgb.merge(s.rename("all"), left_index=True, right_index=True)
df.index.name = "short_url"
df.reset_index(inplace=True)
df["perc"] = df["is_news"] / df["all"] * 100

# %%
df[df["perc"] < 50]
# Out:
#      short_url  is_news  idx  all       perc
# 14     bddy.me        1  0.0    3  33.333333
# 27     dlvr.it        7  0.0   23  30.434783
# 28     dpmd.ai        1  0.0    5  20.000000
# 34  go.usa.gov        1  0.0    4  25.000000
# 35  google.com       20  0.0  206   9.708738
# 39      ift.tt        5  0.0   15  33.333333
# 42     lnkd.in        1  0.0  124   0.806452
# 49     nvda.ws        4  0.0   50   8.000000
# 56       ow.ly       11  0.0   87  12.643678

# %%
short_url[
    (short_url.short_url == "google.com")
    & (short_url.diff_url == True)
    & (short_url.is_news == True)
]
# Out:
#                                                      url  \
# 724    https://www.google.com/amp/s/www.bbc.com/news/...
# 1183   https://www.google.com/amp/s/www.vanityfair.co...
# 1348   https://www.google.com/amp/s/www.washingtonpos...
# 3277   https://www.google.com/amp/s/www.techrepublic....
# 4193   https://www.google.com/amp/s/www.wsj.com/amp/a...
# 4209   https://www.google.com/amp/s/news.sky.com/stor...
# 4618   https://www.google.com/amp/s/wcfcourier.com/ne...
# 5821   https://www.google.com/amp/s/www.wlky.com/amp/...
# 5832   https://www.google.com/amp/s/www.cnn.com/style...
# 6614   https://www.google.com/amp/s/www.zdnet.com/goo...
# 6653   https://www.google.com/amp/s/thenextweb.com/ha...
# 8845   https://www.google.com/amp/s/www.nytimes.com/2...
# 10606  https://www.google.com/amp/s/amp.cnn.com/cnn/2...
# 10977  https://www.google.com/amp/s/mobile.reuters.co...
# 12868  https://www.google.com/amp/s/www.nytimes.com/2...
# 13575  http://feedproxy.google.com/~r/TheGadgeteer/~3...
# 13906  https://www.google.com/amp/s/www.bloomberg.com...
# 14807  https://www.google.com/amp/s/techcrunch.com/20...
# 14865  https://www.google.com/amp/s/www.bbc.com/news/...
# 15826  https://www.google.com/amp/s/www.coindesk.com/...
#
#                                                    title   short_url  \
# 724    Hayabusa-2: Capsule with asteroid samples in '...  google.com
# 1183   Serenity Sets a New Bar for Ridiculous Movie T...  google.com
# 1348                               - The Washington Post  google.com
# 3277   The 50 most overused business cliches - TechRe...  google.com
# 4193   A California Plan to Chase Away the Rich, Then...  google.com
# 4209   COVID-19:Variant found in UK may be more deadl...  google.com
# 4618   After discovering a love for computers, Cedar ...  google.com
# 5821                                  Site Not Available  google.com
# 5832   Italy to build 1,500 pop-up vaccine pavilions,...  google.com
# 6614   Anthropologist 'confirms' Apple is a religion ...  google.com
# 6653   The ‘Bitcoin time-traveler’ Reddit post has be...  google.com
# 8845   Turkey’s Psychedelic Rock Star Speaks Her Mind...  google.com
# 10606  Google threatens to shut down search in Austra...  google.com
# 10977  Chip industry group urges Biden admin to revie...  google.com
# 12868  At the Louvre, Mona Lisa Is Alone, but Still S...  google.com
# 13575  Be more mindful of screentime with Opal – The ...  google.com
# 13906  Startup Good Eggs Raises $100 Million for Expa...  google.com
# 14807          TechCrunch is now a part of Verizon Media  google.com
# 14865       China's curious cult of the mango - BBC News  google.com
# 15826  Nic Carter: The Last Word on Bitcoin's Energy ...  google.com
#
#                  long_url is_news diff_url  idx error links
# 724               bbc.com    True     True  NaN   NaN   NaN
# 1183       vanityfair.com    True     True  NaN   NaN   NaN
# 1348   washingtonpost.com    True     True  NaN   NaN   NaN
# 3277     techrepublic.com    True     True  NaN   NaN   NaN
# 4193              wsj.com    True     True  NaN   NaN   NaN
# 4209              sky.com    True     True  NaN   NaN   NaN
# 4618       wcfcourier.com    True     True  NaN   NaN   NaN
# 5821             wlky.com    True     True  NaN   NaN   NaN
# 5832              cnn.com    True     True  NaN   NaN   NaN
# 6614            zdnet.com    True     True  NaN   NaN   NaN
# 6653       thenextweb.com    True     True  NaN   NaN   NaN
# 8845          nytimes.com    True     True  NaN   NaN   NaN
# 10606             cnn.com    True     True  NaN   NaN   NaN
# 10977         reuters.com    True     True  NaN   NaN   NaN
# 12868         nytimes.com    True     True  NaN   NaN   NaN
# 13575   the-gadgeteer.com    True     True  NaN   NaN   NaN
# 13906       bloomberg.com    True     True  NaN   NaN   NaN
# 14807           yahoo.com    True     True  NaN   NaN   NaN
# 14865             bbc.com    True     True  NaN   NaN   NaN
# 15826        coindesk.com    True     True  NaN   NaN   NaN

# %%
url = "We went into space, found an asteroid, dug up some rocks, and flew it back to Australia. #longhumanity 🚀🚀 https://www.google.com/amp/s/www.bbc.com/news/amp/science-environment-55201662"

# %%
from data import rem_short_links
# my added remove amp to rem_short_links function
rem_short_links(url)
# Out:
# 'We went into space, found an asteroid, dug up some rocks, and flew it back to Australia. #longhumanity 🚀🚀 https://www.bbc.com/news/amp/science-environment-55201662'

# %%
# create list of short urls, I more then 80% times it leads to news site
short_url_list = df[df["perc"] > 50].short_url.tolist()

# %%
short_url_list
# Out:
# ['1843m.ag',
#  '4NN.cx',
#  '53eig.ht',
#  '808ne.ws',
#  'WhiteHouse.gov',
#  'Whitehouse.gov',
#  'abc30.tv',
#  'abc7.la',
#  'abc7ne.ws',
#  'action.consumerreports.org',
#  'afp.com',
#  'apne.ws',
#  'b-gat.es',
#  'bbc.in',
#  'bloom.bg',
#  'bos.gl',
#  'buildbackbetter.gov',
#  'cbsn.ws',
#  'cityjourn.al',
#  'cnb.cx',
#  'cnet.co',
#  'cnn.it',
#  'cntrvlr.co',
#  'cos.lv',
#  'dailym.ai',
#  'econ.st',
#  'ellemag.co',
#  'engt.co',
#  'google.it',
#  'hill.cm',
#  'ja.ma',
#  'jtim.es',
#  'mol.im',
#  'mtr.cool',
#  'natgeo.com',
#  'nationalenquirer.com',
#  'nie.mn',
#  'nym.ag',
#  'nyti.ms',
#  'nytimes.com',
#  'nzzl.us',
#  'on.mktw.net',
#  'on.theatln.tc',
#  'p4k.in',
#  'petitions.whitehouse.gov',
#  'pewrsr.ch',
#  'propub.li',
#  'rdcu.be',
#  'reut.rs',
#  'rol.st',
#  'sabahdai.ly',
#  'sc.mp',
#  'slate.trib.al',
#  'st.news',
#  'str.sg',
#  'tcrn.ch',
#  'tdrt.io',
#  'thr.cm',
#  'ti.me',
#  'tmz.me',
#  'to.pbs.org',
#  'trib.al',
#  'vntyfr.com',
#  'vult.re',
#  'wapo.st',
#  'washex.am',
#  'wdrb.news',
#  'whitehouse.gov.',
#  'wired.trib.al',
#  'yhoo.it',
#  'zd.net']
